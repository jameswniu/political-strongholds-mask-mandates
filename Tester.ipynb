# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import scipy as sts

# %%
filepath = "Resources/mandates_by_state.csv"
MaskMandatesDF = pd.read_csv(filepath)

# %%
MaskMandatesDF.head()

newfp = "Resources/National_Immunization_Survey_Adult_COVID_Module__NIS-ACM___Trends_in_Behavioral_Indicators_Among_Unvaccinated_People.csv"
BehaviorDF = pd.read_csv(newfp)


BehaviorDF.head(50)
# Out:
#               Geography Type Geography  \
# 0         National Estimates  National
# 1         National Estimates  National
# 2         National Estimates  National
# 3         National Estimates  National
# 4         National Estimates  National
# 5         National Estimates  National
# 6         National Estimates  National
# 7         National Estimates  National
# 8         National Estimates  National
# 9         National Estimates  National
# 10        National Estimates  National
# 11        National Estimates  National
# 12        National Estimates  National
# 13        National Estimates  National
# 14        National Estimates  National
# 15        National Estimates  National
# 16        National Estimates  National
# 17        National Estimates  National
# 18        National Estimates  National
# 19        National Estimates  National
# 20        National Estimates  National
# 21        National Estimates  National
# 22        National Estimates  National
# ...

# %%
MaskMandatesDF.sort_values(by=["maskcoverage"], ascending=False)
# Out:
#    state  maskdays    days  maskcoverage
# 11    HI      2430    2465          0.99
# 54    PR     38220   38454          0.99
# 7     CT      3864    3944          0.98
# 55    VI      1407    1479          0.95
# 52    GU       466     493          0.95
# 31    NM     15063   16269          0.93
# 38    PA     29145   33031          0.88
# 32    NY     26908   30566          0.88
# 4     CA     24592   28594          0.86
# 39    RI      2120    2465          0.86
# 22    MI     34777   40919          0.85
# 28    NV      7106    8381          0.85
# 47    WA     16224   19227          0.84
# 30    NJ      8673   10353          0.84
# 9     DE      1233    1479          0.83
# 13    IL     41412   50286          0.82
# 21    MD      9408   11832          0.80
# 19    ME      6208    7888          0.79
# 20    MA      5432    6902          0.79
# 6     DC       386     493          0.78
# 37    OR     13212   17748          0.74
# 48    WV     19140   27115          0.71
# ...
